# %%
# importing pandas as pd 
import pandas as pd 
  
# Creating the time-series index 
ind = pd.date_range('01/01/2000', periods = 6, freq ='W') 
  
# Creating the dataframe  
df = pd.DataFrame({"A":[14, 4, 5, 4, 1, 55], 
                   "B":[5, 2, 54, 3, 2, 32],  
                   "C":[20, 20, 7, 21, 8, 5], 
                   "D":[14, 3, 6, 2, 6, 4]}, index = ind) 
  
# Print the dataframe 
df
# Out:
#              A   B   C   D
# 2000-01-02  14   5  20  14
# 2000-01-09   4   2  20   3
# 2000-01-16   5  54   7   6
# 2000-01-23   4   3  21   2
# 2000-01-30   1   2   8   6
# 2000-02-06  55  32   5   4

# %%
# find the percentage change with the previous row 
df_returns = df.pct_change() 

df_returns.plot(subplots=True,title='Returns');
