# %% [markdown]
# # Data Analysis Pipeline
#
# AirBnB impact on the Chicago housing market 2012-2021
#
# ## Introduction
# - Objective of the analysis:  how do Chicago AirBnB rental rates and prices correlate with house sales and rental prices over time
#
# Primary sources for data are here:
# * Cook county housing price indices quarterly per neighborhood Jan 2000 - June 2023:  https://price-index.housingstudies.org/
#     * Quarterly data which lists "hedonic" housing prices per neighborhood per quarter.  Description of hedonic prices can be found here:  https://ihs-website-v2-production.s3.amazonaws.com/filer_public/2015/05/12/puma_hedonic_model_technical_paper_d7kh29N.pdf
#     * Overall trends plus description of submarkets can be found here: https://www.housingstudies.org/releases/cook-county-house-price-index-second-quarter-2023/
#     * The submarkets in IHS’s price index are based on Public Use Microdata Areas (PUMAs) from the 2010 US Census. There are 16 submarkets in the City of Chicago and 17 that are primarily in suburban Cook County. In the City of Chicago, the submarket surrounding the Loop has been excluded because of insufficient levels of single-family home sales. Click here for a reference guide to the community areas and suburban municipalities found in each submarket. Additional detail about the model can be found at the end of this analysis.
#
# * Rental price information
#   * Overview:  https://www.housingstudies.org/releases/2023-state-rental-housing-city-chicago/
#   * Detailed data capturing deltas in affordability by puma between 2012 and 2019 https://ihs-website-v2-production.s3.amazonaws.com/filer_public/fb/d4/fbd4f2d1-ac9e-4d38-b6f0-b0c40eecebc0/ihs_appendix_sor2023_cook_chicago_suburbs.xlsx
#   * Here is a related article from the Trib about prices in 2023:  https://www.chicagotribune.com/real-estate/ct-biz-rental-market-spring-2023-20230517-ifnesiwvsfaarfugzian3ql6em-story.html
#   * Here is a different source of 2023 rental data: https://www.apartmentlist.com/rent-report/il/chicago
#
# * AirBnB data for Chicago going back a year:  http://insideairbnb.com/get-the-data (pull multiple files for Chicago to get four quarters)  Dec 2022 - Sept 2023
#   * How am I supposed to correlate the available rental and sales data that only goes to 2021 with AirBnB data that is only for 2023?
#
# ## Description of initial Excel analysis
#
#
# ## Importing Libraries and Data
# - Import necessary libraries (e.g., pandas, numpy, matplotlib, seaborn)
#
# - Load the dataset
#
# ## Exploratory Data Analysis (EDA)
# - Data Overview
#   - Display basic information about the dataset (e.g., shape, columns, data types)
#   - Check for missing values
#
# - Summary Statistics
#   - Generate descriptive statistics (e.g., mean, median, min, max)
#
# - Data Visualization
#   - Create visualizations to gain insights (e.g., histograms, scatter plots, box plots)
#
# ## Data Preprocessing
# - Handle Missing Values
#   - Impute or remove missing data
#
# - Data Cleaning
#   - Address any inconsistencies or errors in the data
#
# - Feature Engineering
#   - Create new features if necessary
#
# - Encoding Categorical Variables
#   - Convert categorical variables to numerical format (if needed)
#
#
# ## Conclusion
# - Summarize findings and results
# - Discuss any insights or recommendations
#
# ## Future Work
# - Suggestions for further analysis or improvements
#
# ## References
# - List any sources or libraries used in the analysis
